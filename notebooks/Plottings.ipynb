# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density.dat", unpack=True)
imshow(s)

# %%
s1 = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-oxygen.dat", unpack=True)
s1 /= sum(s1)
imshow(s1)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x9c3ccf8>

# %%
s2 = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-oxygen-basis.dat", unpack=True)
s2 /= sum(s2)
imshow(s2)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xa1383f8>

# %%
s = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-oxygen-diff.dat", unpack=True)
imshow(s)

# %%
s3 = s1 - s2
imshow(s3)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xa537440>

# %%
s1 = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-oxygen.dat", unpack=True)
s1 /= sum(s1)
s1 = log(s1 - s1.min() + 1e-6)
imshow(s1)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x107de200>

# %%
s2 = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-oxygen-basis.dat", unpack=True)
s2 /= sum(s2)
s2 = log(s2 - s2.min() + 1e-6)
imshow(s2)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10a85758>

# %%
s3 = s1 - s2
#s3 = log(s3 - s3.min() + 1e-6)
imshow(s3)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10d27170>

# %%
figure(figsize(10,10))
s = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-double-water.dat", unpack=True)
s = log(s - s.min() + 1e-6)
imshow(s, cmap="YlGnBu_r")
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2169b488>

# %%
figure(figsize(10,10))
s = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-water.dat", unpack=True)
splot = log(s - s.min() + 1e-6)
imshow(splot, cmap="YlGnBu_r")
colorbar()
s.min(), s.max()
# Out:
# (4.4711899999999998e-11, 11273.6)

# %%
figure(figsize(10,10))
sO = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-water0.dat", unpack=True)
sOplot = log(sO - sO.min() + 1e-6)
imshow(sOplot, cmap="YlGnBu_r")
colorbar()
sO.min(), sO.max()
# Out:
# (4.4050499999999997e-11, 11284.9)

# %%
figure(figsize(10,10))
sH1 = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-water1.dat", unpack=True)
sH1plot = log(sH1 - sH1.min() + 1e-6)
imshow(sH1plot, cmap="YlGnBu_r")
colorbar()
sH1.min(), sH1.max()
# Out:
# (6.8330800000000005e-14, 0.0011883)

# %%
figure(figsize(10,10))
sH2 = loadtxt("../../build-hartree-fock-Desktop_Qt_5_1_1_GCC_64bit-Release/tests/density-water2.dat", unpack=True)
sH2plot = log(sH2 - sH2.min() + 1e-6)
imshow(sH2plot, cmap="YlGnBu_r")
colorbar()
sH2.min(), sH2.max()
# Out:
# (6.8330800000000005e-14, 0.0011883)

# %%
sDiff = s - sO - sH1 - sH2
sDiffPlot = sDiff
sDiffPlot[90:110, 90:110] = 0
#sDiffPlot = log(sDiffPlot - sDiffPlot.min() + 1e-6)
imshow(sDiffPlot, cmap="YlGnBu_r")
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x21a625a8>

# %%
imshow(sDiff)
