# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
figure(figsize=(18,12))
for n in range(10,21):
    x,y = loadtxt("/home/svenni/Dropbox/studies/master/code/hartree-fock/build-hartree-fock-tests-uio-Desktop-Debug/results" + str(n) + ".txt", unpack=True)
    plot(x,y, label="n=" + str(n))
    legend()
    xlabel("x")
    ylabel("y")
